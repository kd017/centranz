# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/raw/Table_3_People_Poverty_Selected_Characteristics_2014-2015 .xls")
df.head()
# Out:
#    All People - 2014 - Total  2014 - Below Poverty - Number  \
# 0                     315804                          46657
#
#    2014 - Below Poverty - Number - Margin of error1 (+/-)  \
# 0                                                857
#
#    2014 - Below Poverty - Percent  \
# 0                            14.8
#
#    2014 - Below Poverty - Percent - Margin of error1 (+/-)  2015 - Total  \
# 0                                                0.3              318454
#
#    2015 - Below Poverty - Number  \
# 0                          43123
#
#    2015 - Below Poverty - Number - Margin of error1 (+/-)  \
# 0                                                926
#
#    2015 - Below Poverty - Percent  \
# 0                            13.5
#
#    2015 - Below Poverty - Percent - Margin of error1 (+/-)  \
# 0                                                0.3
#
#   Change in poverty (2015 less 2014)2,* - Number  \
# 0                                        *-3,534
#
# ...

# %%
df2= pd.read_excel("data/raw/Table_3_Poverty Status of People_Age-Race-Hispanic Origin-hstpov3.xls")
df2.head()
# Out:
#   ALL RACES- Year and Characteristic  Under 18 years - All People - Total   \
# 0                               2015                                 73647
# 1                               2014                                 73556
# 2                          2013 (19)                                 73439
# 3                          2013 (18)                                 73625
# 4                               2012                                 73719
#
#    Under 18 years - All People - Below Poverty - Number  \
# 0                                              14509
# 1                                              15540
# 2                                              15801
# 3                                              14659
# 4                                              16073
#
#    Under 18 years - All People - Below Poverty - Percent  \
# 0                                               19.7
# 1                                               21.1
# ...
